# %%
import pandas as pd

# %%
mobot = pd.read_csv("/Users/prince/philly-tree-mapper/notebooks/mobot_plant_data.csv")

# %%
mobot.loc[mobot["Scientific Name"] == "gleditsia triacanthos inermis"]
# Out:
#                    Scientific Name   Bloom Time  \
# 17   gleditsia triacanthos inermis          N/a
# 252  gleditsia triacanthos inermis  May to June
#
#                      Bloom Description         Flower       Leaf  \
# 17                                 N/a            N/a        N/a
# 252  Greenish yellow to greenish white  Insignificant  Good Fall
#
#                    Status                                         Detail URL
# 17   no results container                                                NaN
# 252         manual search  https://www.missouribotanicalgarden.org/PlantF...

# %%
mobot.drop(32, inplace=True)
mobot.drop(17, inplace=True)

# %%
mobot
# Out:
#                    Scientific Name      Bloom Time  \
# 0                    ginkgo biloba           April
# 1                    acer palmatum           April
# 2              acer pseudoplatanus             May
# 3                       ilex opaca             May
# 4          koelreuteria paniculata    June to July
# ..                             ...             ...
# 248                   acer henryii             N/a
# 249                    ulmus alata  March to April
# 250               prunus amanogawa             N/a
# 251            platanus acerifolia           April
# 252  gleditsia triacanthos inermis     May to June
#
#                      Bloom Description         Flower       Leaf  \
# 0                                Green  Insignificant  Good Fall
# 1                       Reddish-purple  Insignificant  Good Fall
# 2                         Yellow green  Insignificant        N/a
# 3                         Creamy white  Insignificant  Evergreen
# ...

# %%
mobot.to_csv("/Users/prince/philly-tree-mapper/notebooks/mobot_plant_data.csv", index=False)
