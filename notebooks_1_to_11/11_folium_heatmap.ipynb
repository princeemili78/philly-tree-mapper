# %%
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
from folium.plugins import HeatMap
import numpy as np
# %matplotlib inline

# %%
trees = gpd.read_file("../data/processed/philly_trees.geojson")

# %%
trees
# Out:
#         objectid                                 tree_name  \
# 0              1                    Ginkgo biloba - ginkgo
# 1              2            Acer palmatum - japanese maple
# 2              3            Acer palmatum - japanese maple
# 3              4            Acer palmatum - japanese maple
# 4              5      Acer pseudoplatanus - sycamore maple
# ...          ...                                       ...
# 150030    151722  Platanus x acerifolia - london planetree
# 150031    151723  Platanus x acerifolia - london planetree
# 150032    151724       Gleditsia triacanthos - honeylocust
# 150033    151725       Gleditsia triacanthos - honeylocust
# 150034    151726       Gleditsia triacanthos - honeylocust
#
#               scientific_name       common_name      Genus         Species  \
# 0               Ginkgo biloba            ginkgo     Ginkgo          biloba
# 1               Acer palmatum    japanese maple       Acer        palmatum
# 2               Acer palmatum    japanese maple       Acer        palmatum
# 3               Acer palmatum    japanese maple       Acer        palmatum
# 4         Acer pseudoplatanus    sycamore maple       Acer  pseudoplatanus
# ...                       ...               ...        ...             ...
# 150030    Platanus acerifolia  london planetree   Platanus      acerifolia
# 150031    Platanus acerifolia  london planetree   Platanus      acerifolia
# 150032  Gleditsia triacanthos       honeylocust  Gleditsia     triacanthos
# 150033  Gleditsia triacanthos       honeylocust  Gleditsia     triacanthos
# 150034  Gleditsia triacanthos       honeylocust  Gleditsia     triacanthos
#
#                           geometry
# 0        POINT (-75.2105 39.98383)
# 1       POINT (-75.21053 39.98374)
# 2       POINT (-75.21041 39.98376)
# 3        POINT (-75.2106 39.98395)
# 4       POINT (-75.21028 39.98376)
# ...                            ...
# 150030  POINT (-75.20873 39.94644)
# 150031   POINT (-75.20876 39.9466)
# 150032  POINT (-75.16226 39.99548)
# 150033   POINT (-75.16221 39.9955)
# 150034  POINT (-75.16216 39.99552)
#
# [150035 rows x 7 columns]
