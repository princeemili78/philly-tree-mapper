# %%
import geopandas as gpd
import pandas as pd
import datetime as dt
pd.set_option('display.max_columns', None)
import numpy as np

# %%
trees = gpd.read_file("/Users/prince/philly-tree-mapper/data/processed/philly_trees_located.geojson")
phenos = gpd.read_file("../data/processed/philly_species_pheno.geojson")

# %%
non_specific_pheno = phenos.loc[phenos["Species"] == "species"]

# %%
non_specific_pheno
# Out:
#      objectid                                 tree_name      scientific_name  \
# 114     16962             Picea species - norway spruce        picea species
# 191        10  Amelanchier species - other serviceberry  amelanchier species
# 193        40             Prunus species - other cherry       prunus species
# 200        65           Malus species - other crabapple        malus species
# 202        84         Magnolia species - other magnolia     magnolia species
# 203       124        Crataegus species - other hawthorn    crataegus species
# 204       156          Aesculus species - other buckeye     aesculus species
# 209       261                 Ulmus species - other elm        ulmus species
# 212       367            Cornus species - other dogwood       cornus species
# 222       705                       Taxus species - yew        taxus species
# 223       772              Salix species - other willow        salix species
# ...

# %%
phenos.loc[phenos["Genus"] == "Cornus"]
# Out:
#      objectid                             tree_name scientific_name  \
# 59      37602    Cornus florida - flowering dogwood  cornus florida
# 60      59585  Cornus mas - corneliancherry dogwood      cornus mas
# 190         9          Cornus kousa - kousa dogwood    cornus kousa
# 212       367        Cornus species - other dogwood  cornus species
# 274     38626      Cornus x rutban - aurora dogwood   cornus rutban
#
#                  common_name   Genus  Species plant_code  \
# 59         flowering dogwood  Cornus  florida      COFL2
# 60   corneliancherry dogwood  Cornus      mas     COMA21
# 190            kousa dogwood  Cornus    kousa        NaN
# 212            other dogwood  Cornus  species        NaN
# 274           aurora dogwood  Cornus   rutban        NaN
#
#     Morphology/Physiology | Active Growth Period  \
# 59                             Spring and Summer
# 60                             Spring and Summer
# 190                                          NaN
# ...

# %%
# Adding phenology information to non generalized tree species
picea_row = {
    'tree_name': 'Picea species - other spruce',
    'scientific_name': 'picea species',
    'common_name': 'other spruce',
    'Genus': 'Picea',
    'Species': 'species',
    'plant_code': np.nan,
    'Morphology/Physiology | Active Growth Period': 'Spring and Summer',
    'Morphology/Physiology | Fall Conspicuous': 'No',
    'Morphology/Physiology | Flower Color': 'Yellow',
    'Morphology/Physiology | Flower Conspicuous': 'No',
    'Morphology/Physiology | Foliage Color': 'Green',
    'Morphology/Physiology | Foliage Porosity Summer': 'Dense',
    'Morphology/Physiology | Foliage Porosity Winter': 'Dense',
    'Morphology/Physiology | Fruit/Seed Color': 'Brown',
    'Morphology/Physiology | Fruit/Seed Conspicuous': 'No',
    'Morphology/Physiology | Leaf Retention': 'Yes',
    'Reproduction | Bloom Period': 'Late Spring',
    'Reproduction | Fruit/Seed Abundance': 'High',
    'Reproduction | Fruit/Seed Period Begin': 'Summer',
    'Reproduction | Fruit/Seed Period End': 'Fall',
    'Suitability/Use | Palatable Human': 'No',
    'Scientific Name': 'picea species',
    'Bloom Time': 'Non-flowering',
    'Bloom Description': 'Non-flowering',
    'Flower': 'N/a',
    'Leaf': 'Evergreen',
    'Status': 'aggregated',
}
phenos.loc[phenos.index[244], list(picea_row.keys())] = list(picea_row.values())

amelanchier_row = {
    'Morphology/Physiology | Active Growth Period': 'Spring and Summer',
    'Morphology/Physiology | Fall Conspicuous': 'Yes',
    'Morphology/Physiology | Flower Color': 'White',
    'Morphology/Physiology | Flower Conspicuous': 'Yes',
    'Morphology/Physiology | Foliage Color': 'Green',
    'Morphology/Physiology | Foliage Porosity Summer': 'Moderate',
    'Morphology/Physiology | Foliage Porosity Winter': 'Porous',
    'Morphology/Physiology | Fruit/Seed Color': 'Red and Purple',
    'Morphology/Physiology | Fruit/Seed Conspicuous': 'Yes',
    'Morphology/Physiology | Leaf Retention': 'No',
    'Reproduction | Bloom Period': 'Spring',
    'Reproduction | Fruit/Seed Abundance': 'Medium',
    'Reproduction | Fruit/Seed Period Begin': 'Spring',
    'Reproduction | Fruit/Seed Period End': 'Summer',
    'Suitability/Use | Palatable Human': 'No',
    'Scientific Name': 'amelanchier species',
    'Bloom Time': 'March to April',
    'Bloom Description': 'White',
    'Flower': 'Showy, Fragrant',
    'Leaf': 'Good Fall',
    'Status': 'aggregated',
}
phenos.loc[phenos.index[191], list(amelanchier_row.keys())] = list(amelanchier_row.values())

prunus_row = {
    'Morphology/Physiology | Active Growth Period': 'Spring and Summer',
    'Morphology/Physiology | Fall Conspicuous': np.nan,
    'Morphology/Physiology | Flower Color': 'Pink to White',
    'Morphology/Physiology | Flower Conspicuous': 'Yes',
    'Morphology/Physiology | Foliage Color': 'Green',
    'Morphology/Physiology | Foliage Porosity Summer': 'Moderate',
    'Morphology/Physiology | Foliage Porosity Winter': 'Porous',
    'Morphology/Physiology | Fruit/Seed Color': 'Red to Black',
    'Morphology/Physiology | Fruit/Seed Conspicuous': 'Yes',
    'Morphology/Physiology | Leaf Retention': 'No',
    'Reproduction | Bloom Period': 'Spring',
    'Reproduction | Fruit/Seed Abundance': 'High',
    'Reproduction | Fruit/Seed Period Begin': 'Summer',
    'Reproduction | Fruit/Seed Period End': 'Summer',
    'Suitability/Use | Palatable Human': 'Yes',
    'Scientific Name': 'prunus species',
    'Bloom Time': 'February to May',
    'Bloom Description': 'White',
    'Flower': 'Showy, Fragrant',
    'Leaf': 'Good Fall',
    'Status': 'aggregated',
}
phenos.loc[phenos.index[193], list(prunus_row.keys())] = list(prunus_row.values())

magnolia_row = {
    'Morphology/Physiology | Active Growth Period': 'Spring and Summer',
    'Morphology/Physiology | Fall Conspicuous': np.nan,
    'Morphology/Physiology | Flower Color': 'Yellow to White',
    'Morphology/Physiology | Flower Conspicuous': 'Yes',
    'Morphology/Physiology | Foliage Color': 'Green',
    'Morphology/Physiology | Foliage Porosity Summer': 'Dense',
    'Morphology/Physiology | Foliage Porosity Winter': 'Moderate',
    'Morphology/Physiology | Fruit/Seed Color': np.nan,
    'Morphology/Physiology | Fruit/Seed Conspicuous': np.nan,
    'Morphology/Physiology | Leaf Retention': np.nan,
    'Reproduction | Bloom Period': 'Spring to Winter',
    'Reproduction | Fruit/Seed Abundance': 'Medium',
    'Reproduction | Fruit/Seed Period Begin': 'Spring',
    'Reproduction | Fruit/Seed Period End': 'Winter',
    'Suitability/Use | Palatable Human': 'No',
    'Scientific Name': 'magnolia species',
    'Bloom Time': 'April to June',
    'Bloom Description': 'Yellow to White',
    'Flower': 'Showy, Fragrant',
    'Leaf': np.nan,
    'Status': 'aggregated',
}
phenos.loc[phenos.index[202], list(magnolia_row.keys())] = list(magnolia_row.values())
crataegus_row = {
    'Morphology/Physiology | Active Growth Period': 'Spring and Summer',
    'Morphology/Physiology | Fall Conspicuous': 'Yes',
    'Morphology/Physiology | Flower Color': 'Purple to White',
    'Morphology/Physiology | Flower Conspicuous': 'Yes',
    'Morphology/Physiology | Foliage Color': 'Green',
    'Morphology/Physiology | Foliage Porosity Summer': 'Dense',
    'Morphology/Physiology | Foliage Porosity Winter': 'Moderate',
    'Morphology/Physiology | Fruit/Seed Color': 'Red',
    'Morphology/Physiology | Fruit/Seed Conspicuous': 'Yes',
    'Morphology/Physiology | Leaf Retention': 'No',
    'Reproduction | Bloom Period': 'Spring',
    'Reproduction | Fruit/Seed Abundance': 'Medium',
    'Reproduction | Fruit/Seed Period Begin': 'Spring',
    'Reproduction | Fruit/Seed Period End': 'Fall',
    'Suitability/Use | Palatable Human': 'No',
    'Scientific Name': 'crataegus species',
    'Bloom Time': 'May to June',
    'Bloom Description': 'White',
    'Flower': 'Showy, Fragrant',
    'Leaf': 'Good Fall',
    'Status': 'aggregated',
}
phenos.loc[phenos.index[203], list(crataegus_row.keys())] = list(crataegus_row.values())
aesculus_row = {
    'Morphology/Physiology | Active Growth Period': 'Spring and Summer',
    'Morphology/Physiology | Fall Conspicuous': 'Yes to No',
    'Morphology/Physiology | Flower Color': 'Yellow to Green to Red',
    'Morphology/Physiology | Flower Conspicuous': 'Yes',
    'Morphology/Physiology | Foliage Color': 'Green',
    'Morphology/Physiology | Foliage Porosity Summer': 'Dense',
    'Morphology/Physiology | Foliage Porosity Winter': 'Porous',
    'Morphology/Physiology | Fruit/Seed Color': 'Brown',
    'Morphology/Physiology | Fruit/Seed Conspicuous': 'Yes',
    'Morphology/Physiology | Leaf Retention': 'No',
    'Reproduction | Bloom Period': 'Mid Spring to Late Spring',
    'Reproduction | Fruit/Seed Abundance': 'Medium',
    'Reproduction | Fruit/Seed Period Begin': 'Spring to Summer',
    'Reproduction | Fruit/Seed Period End': 'Fall',
    'Suitability/Use | Palatable Human': 'No',
    'Scientific Name': 'aesculus species',
    'Bloom Time': 'April to May',
    'Bloom Description': 'Yellow to Red',
    'Flower': 'Showy',
    'Leaf': np.nan,
    'Status': 'aggregated',
}
phenos.loc[phenos.index[204], list(aesculus_row.keys())] = list(aesculus_row.values())
ulmus_row = {
    'Morphology/Physiology | Active Growth Period': 'Spring and Summer',
    'Morphology/Physiology | Fall Conspicuous': 'Yes to No',
    'Morphology/Physiology | Flower Color': 'Yellow to Green',
    'Morphology/Physiology | Flower Conspicuous': 'No',
    'Morphology/Physiology | Foliage Color': 'Green',
    'Morphology/Physiology | Foliage Porosity Summer': 'Dense',
    'Morphology/Physiology | Foliage Porosity Winter': 'Porous',
    'Morphology/Physiology | Fruit/Seed Color': 'Brown',
    'Morphology/Physiology | Fruit/Seed Conspicuous': 'No',
    'Morphology/Physiology | Leaf Retention': 'No',
    'Reproduction | Bloom Period': 'Early Spring to Late Summer',
    'Reproduction | Fruit/Seed Abundance': 'Medium to High',
    'Reproduction | Fruit/Seed Period Begin': 'Spring',
    'Reproduction | Fruit/Seed Period End': 'Spring',
    'Suitability/Use | Palatable Human': 'No',
    'Scientific Name': 'ulmus species',
    'Bloom Time': np.nan,
    'Bloom Description': 'Reddish green',
    'Flower': 'Insignificant',
    'Leaf': np.nan,
    'Status': 'aggregated',
}


phenos.loc[phenos.index[209], list(ulmus_row.keys())] = list(ulmus_row.values())
cornus_row = {
    'Morphology/Physiology | Active Growth Period': 'Spring and Summer',
    'Morphology/Physiology | Fall Conspicuous': 'Yes',
    'Morphology/Physiology | Flower Color': 'White to Yellow',
    'Morphology/Physiology | Flower Conspicuous': 'Yes',
    'Morphology/Physiology | Foliage Color': 'Green',
    'Morphology/Physiology | Foliage Porosity Summer': 'Porous to Dense',
    'Morphology/Physiology | Foliage Porosity Winter': 'Porous to Moderate',
    'Morphology/Physiology | Fruit/Seed Color': 'Red',
    'Morphology/Physiology | Fruit/Seed Conspicuous': 'Yes',
    'Morphology/Physiology | Leaf Retention': 'No',
    'Reproduction | Bloom Period': 'Early Spring to Mid Spring',
    'Reproduction | Fruit/Seed Abundance': 'Medium to High',
    'Reproduction | Fruit/Seed Period Begin': 'Spring',
    'Reproduction | Fruit/Seed Period End': 'Summer to Fall',
    'Suitability/Use | Palatable Human': 'No',
    'Scientific Name': 'cornus species',
    'Bloom Time': 'May to June',
    'Bloom Description': 'White (bracts) to Yellow to White to Pinkish',
    'Flower': 'Showy',
    'Leaf': 'Good Fall',
    'Status': 'aggregated',
}

# Replace IDX with the target row index
phenos.loc[phenos.index[212], list(cornus_row.keys())] = list(cornus_row.values())

# %% [markdown]
# Skipping malus. Dont know enough about them to make a generalization for 3k trees. Return later?
# Stopped at Taxus. Testing writing a df function

# %%
non_specifc_genus_list = list(non_specific_pheno["Genus"])
non_specifc_genus_list = [genus for genus in non_specifc_genus_list if genus != "Malus"]
unique_non_specifc_genus_list= list(dict.fromkeys(non_specifc_genus_list))

# %%
def aggregate_values(species: str):
    """Parse through trees that were matched with USDA or MOBOT data and apply them to trees that philly observers only got genus for"""
    columns = [
        'Morphology/Physiology | Active Growth Period',
        'Morphology/Physiology | Fall Conspicuous',
        'Morphology/Physiology | Flower Color',
        'Morphology/Physiology | Flower Conspicuous',
        'Morphology/Physiology | Foliage Color',
        'Morphology/Physiology | Foliage Porosity Summer',
        'Morphology/Physiology | Foliage Porosity Winter',
        'Morphology/Physiology | Fruit/Seed Color',
        'Morphology/Physiology | Fruit/Seed Conspicuous',
        'Morphology/Physiology | Leaf Retention',
        'Reproduction | Bloom Period',
        'Reproduction | Fruit/Seed Abundance',
        'Reproduction | Fruit/Seed Period Begin',
        'Reproduction | Fruit/Seed Period End',
        'Suitability/Use | Palatable Human',
        'Bloom Time', 'Bloom Description',
        'Flower', 'Leaf',
    ]

    df = phenos.loc[phenos["Genus"] == species].reset_index(drop=True)
    idx = phenos.index[phenos["scientific_name"] == f"{species.lower()} species"].to_list()
    if not idx:
        print(f"No aggregate row for '{species.lower()} species'")
        return

    for col in columns:
        if phenos[col].dtype != object:
            phenos[col] = phenos[col].astype(object)

        values = []
        for val in df[col]:
            if pd.isna(val):
                continue
            if val in values:
                continue
            values.append(val)

        phenos.at[idx[0], col] = values
        phenos.at[idx[0], "Status"] = "aggregated"

# %%
phenos.loc[phenos["Genus"] == "Picea"]
# Out:
#                            tree_name scientific_name      common_name  Genus  \
# 114    Picea species - norway spruce   picea species    norway spruce  Picea
# 115      Picea glauca - white spruce    picea glauca     white spruce  Picea
# 116     Picea mariana - black spruce   picea mariana     black spruce  Picea
# 118  Picea pungens - colorado spruce   picea pungens  colorado spruce  Picea
# 244     Picea species - other spruce   picea species     other spruce  Picea
#
#      Species plant_code Morphology/Physiology | Active Growth Period  \
# 114  species       PIAB                  [Spring and Summer, Summer]
# 115   glauca       PIGL                                       Summer
# 116  mariana       PIMA                                       Summer
# 118  pungens       PIPU                            Spring and Summer
# 244  species        NaN                                          NaN
#
#     Morphology/Physiology | Fall Conspicuous  \
# ...

# %%
aggregate_values("Pinus")

# %%
phenos.loc[phenos["Genus"] == "Cupressus"]
# Out:
#      objectid                          tree_name    scientific_name  \
# 262     18578  Cupressus species - other cypress  cupressus species
#
#        common_name      Genus  Species plant_code  \
# 262  other cypress  Cupressus  species        NaN
#
#     Morphology/Physiology | Active Growth Period  \
# 262                                           []
#
#     Morphology/Physiology | Fall Conspicuous  \
# 262                                       []
#
#     Morphology/Physiology | Flower Color  \
# 262                                   []
#
#     Morphology/Physiology | Flower Conspicuous  \
# 262                                         []
#
#     Morphology/Physiology | Foliage Color  \
# 262                                    []
#
#     Morphology/Physiology | Foliage Porosity Summer  \
# 262                                              []
#
#     Morphology/Physiology | Foliage Porosity Winter  \
# 262                                              []
#
# ...

# %%
for idx in range(len(unique_non_specifc_genus_list)):
    aggregate_values(unique_non_specifc_genus_list[idx])

# %%
non_specific_pheno = phenos.loc[phenos["Species"] == "species"]

# %%
non_specific_pheno
# Out:
#      objectid                                 tree_name      scientific_name  \
# 114     16962             Picea species - norway spruce        picea species
# 191        10  Amelanchier species - other serviceberry  amelanchier species
# 193        40             Prunus species - other cherry       prunus species
# 200        65           Malus species - other crabapple        malus species
# 202        84         Magnolia species - other magnolia     magnolia species
# 203       124        Crataegus species - other hawthorn    crataegus species
# 204       156          Aesculus species - other buckeye     aesculus species
# 209       261                 Ulmus species - other elm        ulmus species
# 212       367            Cornus species - other dogwood       cornus species
# 222       705                       Taxus species - yew        taxus species
# 223       772              Salix species - other willow        salix species
# ...

# %%
phenos = phenos.drop(columns=["objectid", "geometry", "Detail URL"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 phenos = phenos.drop(columns=["objectid", "geometry", "Detail URL"])
#       2 phenos
#
# File ~/philly-tree-mapper/venv/lib/python3.14/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File ~/philly-tree-mapper/venv/lib/python3.14/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
#phenos.to_csv("/Users/prince/philly-tree-mapper/data/processed/philly_species_pheno.csv", index=False)
